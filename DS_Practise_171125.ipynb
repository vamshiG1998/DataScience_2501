# %% [markdown]
# <a href="https://colab.research.google.com/github/vamshiG1998/DataScience_2501/blob/main/DS_Practise_171125.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Gradient Descent

import numpy as np
import matplotlib.pyplot as plt

X = np.array([1,2,3,4,5])
y = np.array([2,4,6,8,10])

m = len(y)

# Initialize Parameters
theta = 0.0 #slope of the line that best fits the MSE
alpha = 0.1
iterations = 1000

for i in range(iterations):
  y_pred = theta * X
  cost = (1/(2*m)) * np.sum((y_pred - y )**2)
  gradient = (1/m) * np.sum((y_pred - y) * X)
  theta = theta - (alpha * gradient)

  print("Optimized theta:", theta)
  print("final cost", cost)

  plt.scatter(X,y, color ='blue', label = 'Data')
  plt.plot(X,theta*X, color = 'red', label = 'Fitted Line')
  plt.xlabel("X")
  plt.ylabel("y")
  plt.legend()
  plt.show()
# Out:
# Optimized theta: 2.2
# final cost 22.0
# Optimized theta: 1.98
# final cost 0.2200000000000002
# Optimized theta: 2.002
# final cost 0.0022000000000000006
# Optimized theta: 1.9998
# final cost 2.199999999999338e-05
# Optimized theta: 2.00002
# final cost 2.19999999999916e-07
# Optimized theta: 1.9999980000000002
# final cost 2.2000000000110617e-09
# Optimized theta: 2.0000002
# final cost 2.199999999673554e-11
# Optimized theta: 1.99999998
# final cost 2.2000000029242871e-13
# Optimized theta: 2.000000002
# final cost 2.2000000380961527e-15
# Optimized theta: 1.9999999998
# final cost 2.2000003640576475e-17
# Optimized theta: 2.00000000002
# final cost 2.2000003640576475e-19
# Optimized theta: 1.999999999998
# final cost 2.2000003640576475e-21
# Optimized theta: 2.0000000000002
# final cost 2.1997428018595614e-23
# Optimized theta: 1.99999999999998
# final cost 2.194710434798913e-25
# Optimized theta: 2.0000000000000018
# final cost 2.1929741519465214e-27
# ...

# %%
import pandas as pd
import seaborn as sns

data = {'hours':[1,2,4,3,5,3,4,2], 'marks':[5,20,44,52,70,83,99,55]}
df = pd.DataFrame(data)

sns.histplot(df['marks'], bins=10,color='skyblue')
plt.title('Distribution of marks')
plt.xlabel('marks')
plt.ylabel('frequency')
plt.show()
